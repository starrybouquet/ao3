# %%
import os
import sys
import random
import urllib.parse
import time
import re

import markovify
import json
from bs4 import BeautifulSoup
import spacy

sys.path.insert(0, os.path.abspath('..'))

import ao3
from ao3.utils import work_id_from_url
from ao3.works import Work

# %%
def add_work_to_chain(work, models, state_size=3):
    '''adds new Markov chain model of work
    with given ID to the dict models and returns said dict'''
    text = work.get_work_text()
    model = markovify.Text(text, state_size=state_size)
    models[str(work.id)] = model
    print('Added work {} to models.'.format(work.title))

    return models

# %%
def load_data():
    with open('data.txt', 'r') as f:
        raw_data = f.readlines()

    bookmark_data = {}
    in_bookmark = False
    ending_bookmark = False
    current_id = '3413384'
    current_data = ''
    for line in raw_data:
        if ending_bookmark:
            # print('Bookmark is ending')
            ending_bookmark = False
            parts = line.partition('>')
            current_data += parts[0]
            current_data += parts[1]
            # print('Partitioned line: {}'.format(parts))
            bookmark_data[current_id] = current_data # add tag to dict
            # print('Assigned current data to id {}'.format(current_id))
            current_id = parts[2].strip() # assign next id
            # print('Assigned next id as {}'.format(current_id))
            current_data = ''
        else:
            current_data += line
            if '<div class="recent dynamic"' in line:
                ending_bookmark = True
                # print('Turned on ending bookmark')
    
    print('Logging in...')
    api.login('starrybouquet')
    all_works = []
    for id, html in bookmark_data.items():
        soup = BeautifulSoup(html, 'html.parser')
        all_works.append(Work(id, api.handler, load=False, soup=soup))
        
    possible_tags = set(['Samantha "Sam" Carter/Jack O\'Neill', 'Jack/Sam', 'Sam/Jack', 'Sam Carter/Jack O\'Neill'])
    matching_works = []
    for work in all_works:
        ship = set(work.relationship)
        intersection = possible_tags.intersection(ship)
        if len(intersection) > 0:
            matching_works.append(work)
    print('Works matching tags: ')
    print(len(matching_works))
    return matching_works

# %%
def create_models(works):
    models = {} # each entry is id: model
    ids = []
    
    models_built = 1
    for work in works:
        print('Building model {}...'.format(models_built))
        if models_built % 40 == 0:
            print('{} models built, sleeping 3 min'.format(models_built))
            time.sleep(180)
        models = add_work_to_chain(work, models)
        models_built += 1
    print('Done building models.')
    print('keys of model dict:')
    print(models.keys())
    return models

# %%
api = ao3.AO3()
works = load_data()
input('Press Enter to continue: ')
models = create_models(works)
# Out:
# Logging in...
# Authentication successful. You are logged in.
# Works matching tags:
# 179
# Building model 1...
# Added work Auctions and Consequences to models.
# Building model 2...
# Added work Better or Right to models.
# Building model 3...
# Added work dark switch to models.
# Building model 4...
# Added work level three, advanced to models.
# Building model 5...
# Added work If the World was Ending to models.
# Building model 6...
# Added work Walking the Dog to models.
# Building model 7...
# Added work a shine of light and a circle of blue to models.
# Building model 8...
# Added work F*@kingPete to models.
# Building model 9...
# Added work T-minus a Lifetime to models.
# Building model 10...
# Added work Walking on Broken Glass to models.
# Building model 11...
# Added work Singing to models.
# Building model 12...
# Added work Despair and hope to models.
# Building model 13...
# Added work Make it rain to models.
# Building model 14...
# Added work Revelations to models.
# Building model 15...
# Added work Solstitium, Interrupted to models.
# Building model 16...
# Added work When A Present Falls Into Your Lap, Don't Ask to models.
# Building model 17...
# Added work rhenium to models.
# Building model 18...
# Added work  to models.
# Building model 19...
# Added work Obelisks and Existentialism to models.
# Building model 20...
# Added work Memory Feeds Imagination to models.
# Building model 21...
# Added work Bedroom Situation to models.
# Building model 22...
# Added work Communication to models.
# Building model 23...
# Added work Like An Old Soldier to models.
# Building model 24...
# Added work The Reality of Dreams to models.
# Building model 25...
# Added work Reminiscit to models.
# Building model 26...
# Added work Epiphany in Motion to models.
# Building model 27...
# Added work He Chose Ice to models.
# Building model 28...
# Added work Desperation to models.
# Building model 29...
# Added work Punch The Clock to models.
# Building model 30...
# Added work My Wonderland to models.
# Building model 31...
# Added work Cherry Turnovers And Cheery Dispositions to models.
# Building model 32...
# Added work Interruptus to models.
# Building model 33...
# Added work Five Times Sam and Jack got Accidentally Married (And One Time They Didn't) to models.
# Building model 34...
# Added work And They Danced To Their Own Beat to models.
# Building model 35...
# Added work Hot Medal to models.
# Building model 36...
# Added work Dress Blues to models.
# Building model 37...
# Added work An Upended House to models.
# Building model 38...
# Added work Plans Change to models.
# Building model 39...
# Added work Kernel to models.
# Building model 40...
# 40 models built, sleeping 3 min
# Added work Blush to models.
# Building model 41...
# Added work Truth be Told to models.
# Building model 42...
# Added work Battling Nightmares Together to models.
# Building model 43...
# Added work The Stillness Between to models.
# Building model 44...
# Added work Compulsion to models.
# Building model 45...
# Added work 2010 to models.
# Building model 46...
# Added work Jack's Appeal to models.
# Building model 47...
# Added work Surface Tension to models.
# Building model 48...
# Added work Things Not Said to models.
# Building model 49...
# Added work Reason to Breathe to models.
# Building model 50...
# Added work Reach! to models.
# Building model 51...
# Added work Growing up Human to models.
# Building model 52...
# Added work Open Window to models.
# Building model 53...
# Added work The Stupidest Question to models.
# Building model 54...
# Added work The Sweetest Words to models.
# Building model 55...
# Added work Do you trust me Carter? to models.
# Building model 56...
# Added work SG-1 And A Baby Makes Five (you do the math) to models.
# Building model 57...
# Added work clowns to the left of me, jokers to the right to models.
# Building model 58...
# Added work Someone To Watch Over Me to models.
# Building model 59...
# Added work The Conversation to models.
# Building model 60...
# Added work "Anything, just call me, okay?" to models.
# Building model 61...
# Added work Rough Day to models.
# Building model 62...
# Added work Tied in a Bow to models.
# Building model 63...
# Added work Scotch Tape and Christmas Eve to models.
# Building model 64...
# Added work The Promise to models.
# Building model 65...
# Added work Seven Down to models.
# Building model 66...
# Added work The Mark of Anam to models.
# Building model 67...
# Added work Trust Me to models.
# Building model 68...
# Added work Paradise Rescue to models.
# Building model 69...
# Added work My Everything to models.
# Building model 70...
# Added work Those Things You Said to models.
# Building model 71...
# Added work Still, and Always to models.
# Building model 72...
# Added work Shockwave to models.
# Building model 73...
# Added work Dog Tags to models.
# Building model 74...
# Added work Overload to models.
# Building model 75...
# Added work Love Unbroken to models.
# Building model 76...
# Added work He Breathes Her In to models.
# Building model 77...
# Added work Promises Fulfilled: Sam to models.
# Building model 78...
# Added work In dreams to models.
# Building model 79...
# Added work Too Many Excuses to models.
# Building model 80...
# 80 models built, sleeping 3 min
# Added work Paper Flowers to models.
# Building model 81...
# Added work Enough to models.
# Building model 82...
# Added work Bad Dreams to models.
# Building model 83...
# Added work Rites of passage to models.
# Building model 84...
# Added work Hidden Meanings In Everyday Conversations to models.
# Building model 85...
# Added work Hat Trick to models.
# Building model 86...
# Added work Locked in a Room to models.
# Building model 87...
# Added work  to models.
# Building model 88...
# Added work someday is not good enough (when I love you so much) to models.
# Building model 89...
# Added work Asters to models.
# Building model 90...
# Added work Unite and Surrender to models.
# Building model 91...
# Added work Knowing to models.
# Building model 92...
# Added work Beauty to models.
# Building model 93...
# Added work Reflection of Us to models.
# Building model 94...
# Added work Balms and Bandages to models.
# Building model 95...
# Added work Gift Horse to models.
# Building model 96...
# Added work For the Fishing to models.
# Building model 97...
# Added work First Breath After Coma to models.
# Building model 98...
# Added work Diner Mornings to models.
# Building model 99...
# Added work Punnett Results to models.
# Building model 100...
# Added work Tezkarni – Remember Me to models.
# Building model 101...
# Added work What's Your Poison? to models.
# Building model 102...
# Added work An Open Window to models.
# Building model 103...
# Added work Stuck On You to models.
# Building model 104...
# Added work Goo Gone to models.
# Building model 105...
# Added work Containment to models.
# Building model 106...
# Added work being with you gets me that way (just breathe) to models.
# Building model 107...
# Added work Promise to models.
# Building model 108...
# Added work 2001 to models.
# Building model 109...
# Added work Spring Break to models.
# Building model 110...
# Added work That's something to models.
# Building model 111...
# Added work In your hands to models.
# Building model 112...
# Added work al-Hab Ho - Love Is to models.
# Building model 113...
# Added work Catherine's Letter to models.
# Building model 114...
# Added work Blue Moon to models.
# Building model 115...
# Added work The Universal Language to models.
# Building model 116...
# Added work Barefoot to models.
# Building model 117...
# Added work Footloose to models.
# Building model 118...
# Added work Written in the Stars to models.
# Building model 119...
# Added work Small Victories to models.
# Building model 120...
# 120 models built, sleeping 3 min
# Added work Anything Cliché to models.
# Building model 121...
# Added work Nehme - Blessing to models.
# Building model 122...
# Added work Amongst the Dust to models.
# Building model 123...
# Added work She Don't Know She's Beautiful to models.
# Building model 124...
# Added work the art of dating to models.
# Building model 125...
# Added work Next to her heart to models.
# Building model 126...
# Added work Blowing Off Steam to models.
# Building model 127...
# Added work Urgo to models.
# Building model 128...
# Added work one more round to models.
# Building model 129...
# Added work you brought music back into the house to models.
# Building model 130...
# Added work What Do You Do With a General? to models.
# Building model 131...
# Added work The Perfect Gift to models.
# Building model 132...
# Added work Birthday Surprise to models.
# Building model 133...
# Added work Five Pieces of Furniture to models.
# Building model 134...
# Added work Rules of Engagement to models.
# Building model 135...
# Added work Life Lessons to models.
# Building model 136...
# Added work Distant Stars to models.
# Building model 137...
# Added work Together to models.
# Building model 138...
# Added work School's Out to models.
# Building model 139...
# Added work The Consequences of Forgetting Beer to models.
# Building model 140...
# Added work The unexpected kisses to models.
# Building model 141...
# Added work Smaller Victories to models.
# Building model 142...
# Added work Can't Fight This Feeling to models.
# Building model 143...
# Added work Soldier On to models.
# Building model 144...
# Added work Forget I Even Asked You to models.
# Building model 145...
# Added work First Times and Second Chances to models.
# Building model 146...
# Added work Blind Date to models.
# Building model 147...
# Added work Overrated to models.
# Building model 148...
# Added work Georgia's wedding date fic to models.
# Building model 149...
# Added work Cause A Day Can Get So Long to models.
# Building model 150...
# Added work Strange Statues to models.
# Building model 151...
# Added work All Her Colors to models.
# Building model 152...
# Added work Never Say Die to models.
# Building model 153...
# Added work Hidden Talents to models.
# Building model 154...
# Added work Patience to models.
# Building model 155...
# Added work Roommates to models.
# Building model 156...
# Added work The Fountain to models.
# Building model 157...
# Added work Five Nights in Nottingham to models.
# Building model 158...
# Added work Intruder Alert to models.
# Building model 159...
# Added work grow me a garden worthy of you to models.
# Building model 160...
# 160 models built, sleeping 3 min
# Added work Body Checked to models.
# Building model 161...
# Added work Proper Care and Feeding of Your Astrophysicist to models.
# Building model 162...
# Added work Badfic!Pete And The Temple of Doom to models.
# Building model 163...
# Added work Jaunt to Paradise to models.
# Building model 164...
# Added work Years Ago to models.
# Building model 165...
# Added work Xanadu to models.
# Building model 166...
# Added work The Pier to models.
# Building model 167...
# Added work Lifelines to models.
# Building model 168...
# Added work HopeLights to models.
# Building model 169...
# Added work Serendipity to models.
# Building model 170...
# Added work Embrace Me to models.
# Building model 171...
# Added work Fever to models.
# Building model 172...
# Added work Small Steps and Giant Leaps to models.
# Building model 173...
# Added work Anchor to models.
# Building model 174...
# Added work Full Disclosure to models.
# Building model 175...
# Added work The Dreams We Left Behind to models.
# Building model 176...
# Added work A Whole Alphabet of Plans to models.
# Building model 177...
# Added work en fermant les yeux to models.
# Building model 178...
# Added work our hearts are holding hands to models.
# Building model 179...
# Added work Five Times Sam Gets Married to models.
# Done building models.
# keys of model dict:
# dict_keys(['3413384', '15321831', '17595899', '20730641', '25569304', '386073', '13293435', '15894018', '26677279', '25672171', '58119', '58118', '17454290', '26487811', '26435635', '26424511', '14787017', '3074828', '21685909', '22786924', '588184', '204232', '16871', '8415589', '24043948', '26220838', '9333437', '134933', '17566991', '1320223', '26166262', '26135494', '26091934', '26089615', '16721448', '1503401', '26063671', '193358', '14348877', '10414422', '10551086', '25877506', '25827544', '20048035', '19193608', '24920743', '25714585', '2846372', '1092517', '438517', '25691269', '461625', '3292169', '6113039', '25540522', '13468128', '14586021', '14706062', '15137486', '15191513', '15357387', '17121293', '17133743', '20250496', '25620136', '15841485', '10739001', '5667358', '25594993', '25574875', '25568437', '25555795', '25565821', '15842640', '25460851', '25468321', '627702', '24759118', '20730965', '2460653', '5230241', '2493851', '1004942', '16728498', '14464032', '14078604', '24342595', '17652089', '18730279', '9711971', '204230', '24550843', '17111540', '5309255', '24274261', '24247543', '24222202', '24221422', '24056014', '22636693', '17534309', '23752213', '23701897', '23712724', '23648950', '23616367', '23565454', '1139715', '1141749', '22737646', '19155310', '20978024', '22555867', '1705565', '1707053', '18760267', '18836563', '15539424', '18931405', '17722562', '20230660', '246889', '635813', '17688413', '18736057', '13723254', '20301340', '14955101', '15157991', '412934', '388195', '415100', '415425', '1705574', '777545', '14350638', '116580', '436758', '437643', '951869', '1150116', '1556414', '1092593', '15022220', '19210318', '16084616', '18588790', '20403058', '478991', '16806', '7244251', '198309', '20030677', '19638', '204236', '1206376', '1481152', '777730', '14565489', '15088637', '17315486', '198333', '198299', '198311', '198296', '4921702', '4727156', '9134434', '189162', '221870', '221819', '221863', '569654', '1142831', '2135820', '133729', '16765762', '16463123', '16434491'])

# %%
json_models = {}
models_list = []
for workid, model in models.items():
    json_model = model.to_json()
    json_models[workid] = json_model

# %%
with open('work_models.json', 'w') as file:
    json.dump(json_models,file)

# %%
# load
with open('work_models.json', 'r') as f:
    raw = f.read()
print(raw[:1000])
models_from_json = json.loads(raw)
modelList = []
models = {}
for workid, model_json in models_from_json.items():
    actual_model = markovify.Text.from_json(model_json)
    modelList.append(actual_model)
    models[str(workid)] = actual_model
print('Models loaded')
# Out:
# {"3413384": "{\"state_size\": 3, \"chain\": \"[[[\\\"___BEGIN__\\\", \\\"___BEGIN__\\\", \\\"___BEGIN__\\\"], {\\\"Colonel\\\": 1, \\\"Daniel\\\": 12, \\\"Their\\\": 1, \\\"Putting\\\": 1, \\\"The\\\": 12, \\\"There\\\": 8, \\\"No\\\": 2, \\\"This\\\": 5, \\\"Then\\\": 1, \\\"Not\\\": 5, \\\"And\\\": 3, \\\"Now,\\\": 1, \\\"Teal'c's\\\": 1, \\\"With\\\": 3, \\\"Or,\\\": 2, \\\"I'm\\\": 3, \\\"However,\\\": 1, \\\"Jack\\\": 34, \\\"So\\\": 2, \\\"Teal'c\\\": 7, \\\"Considering\\\": 3, \\\"He\\\": 29, \\\"Daniel,\\\": 1, \\\"Why\\\": 2, \\\"No,\\\": 2, \\\"Still,\\\": 2, \\\"A\\\": 4, \\\"From\\\": 3, \\\"They'll\\\": 1, \\\"We\\\": 3, \\\"They\\\": 3, \\\"As\\\": 4, \\\"If\\\": 1, \\\"Killing\\\": 1, \\\"They're\\\": 3, \\\"I\\\": 2, \\\"Don't\\\": 1, \\\"Yeah,\\\": 1, \\\"It\\\": 6, \\\"Disgusted,\\\": 1, \\\"Her\\\": 12, \\\"Boots\\\": 1, \\\"Plus,\\\": 1, \\\"After\\\": 1, \\\"Carter\\\": 12, \\\"She\\\": 22, \\\"Almost\\\": 1, \\\"On\\\": 1, \\\"Wary\\\": 1, \\\"Getting\\\": 1, \\\"
# Models loaded

# %%
def combine_models(models, weights=None):
    if not weights:
        model = markovify.combine(models)
    else:
        model = markovify.combine(models, weights)
    return model.compile()

# %%
# combine
full_model = combine_models(modelList)
num_sentences = int(input('Enter # of sentences to try: '))
for i in range(num_sentences):
    print(full_model.make_sentence())

save = str(input('Do you want to save this model? y or n: '))
if save == 'y':
    filename = str(input('Enter filename to save: '))
    json_model = full_model.to_json()
    with open(filename, 'w') as f:
        json.dump(json_model, f)
    print('Saved file.')
# Out:
# Or rather, one side of his neck, and her fingers trace a slow, deliberate caress from his shoulder blade to his waist, and his fingers pressing at her entrance and then he goes on talking about a deceased loved one.
# He calls her cell phone and fished around in her mind.
# None
# Their eyes met, and this time held up a hand when he made to speak.
# What to say to her.
# Five minutes later she’s in her lab, hoping she’d get to find one of them.
# And when she’d told him that maybe she was in his arms and wrapped herself so tightly around his hips, pressing him closer and he tears at the material instead.
# Jack bit back a smile.
# “You know,” he shrugged as he took a couple of times, but he doesn’t speak until he climbs the ramp to stand at the door.“What?” he grins.
# She always knew what to say or at least one of their silent conversations.
# She thinks she slept for a while, they were happy.
# Someone was going to pull the hose off, after which he repeated the process she had done just that.
# The music faded into the distance and the people around him need to start back from zero.
# And it was only a momentary emotion.
# Maybe she had gone to her head.Because suddenly, her lips were parted slightly.
# Saved file. IDs used were:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-cc1955d2f8cd> in <module>
#      12         json.dump(json_model, f)
#      13     print('Saved file. IDs used were:')
# ---> 14     print(ids)
#
# NameError: name 'ids' is not defined

# %%
num_sentences = int(input('Enter # of sentences to try: '))
for i in range(num_sentences):
    print(full_model.make_sentence())
# Out:
# Instead, he stood his ground and closed the door and walking past him to work on the other side of a pillar several hundred feet away.
# Her eyes lit up with an explanation until finally it dawned her exactly what Jack was trying to hide a smile behind her hand.“You’re laughing at me.”She turned and wrapped her arms around her body to relax.“I know,” he says, stroking her back.
# *Day 1, One Week Earlier* “Carter, I swear to God if I have to get them any higher.
# I thought it was super glue?” he protested, yet still careful to keep the truth from themselves than it was in those intimate, stolen moments that Jacob saw a side to the two pieces popped back where they belonged.At least they went back where they belonged.At least they went back where they belonged.
# The scent of him that didn’t want her to dwell on the possibility of them.
# She leaned next to him on the couch, folding her leg underneath her and facing him.
# There are the usual flowers and seating plans in the lobby but none of it had been Hathor’s goa’uld and then the stasis pod and checked the controls.
# Glancing into her cart, she looked at her with concern.
# Don’t you think I didn’t?”
# It was nice, for awhile, being alone with his shower, alone with his thoughts in hazy confusion.
# “I’d like to accept the weight of them against the backs of her hands.
# Jack had to admit the doctor of political sciences seemed to be paying no attention to the fact that they draw eyes is probably a bad idea.”“I don’t know,” she says honestly.
# From the looks of it.
# She made it as far as the wall near the door had stopped dancing and were watching them—watching her.
# The surprise on her face and laughs.
# He leaned forward when her voice filters into the hallway, not the briefing room, and left.Looking up at the table.
# She would hate him, or he would hate them for it.
# She jabs the call button and took a step towards her.
# He'd penned his name on it, and Jack stayed near her while the tremors of her sobs shook her body.
# He wondered briefly whether she even realized she was slipping into a nightmare.

# %%
nlp = spacy.load("en_core_web_sm")

class POSifiedText(markovify.Text):
    def word_split(self, sentence):
        return ["::".join((word.orth_, word.pos_)) for word in nlp(sentence)]

    def word_join(self, words):
        sentence = " ".join(word.split("::")[0] for word in words)
        return sentence

# %%
# load
with open('work_models.json', 'r') as f:
    raw = f.read()
models_from_json = json.loads(raw)
modelList = []
models = {}
for workid, model_json in models_from_json.items():
    actual_model = POSifiedText.from_json(model_json)
    modelList.append(actual_model)
    models[str(workid)] = actual_model
print('Models loaded')


# combine
full_model = combine_models(modelList)
num_sentences = int(input('Enter # of sentences to try: '))
for i in range(num_sentences):
    print(full_model.make_sentence())

save = str(input('Do you want to save this model? y or n: '))
if save == 'y':
    filename = str(input('Enter filename to save: '))
    json_model = full_model.to_json()
    with open(filename, 'w') as f:
        json.dump(json_model, f)
    print('Saved file.')
# Out:
# {"3413384": "{\"state_size\": 3, \"chain\": \"[[[\\\"___BEGIN__\\\", \\\"___BEGIN__\\\", \\\"___BEGIN__\\\"], {\\\"Colonel\\\": 1, \\\"Daniel\\\": 12, \\\"Their\\\": 1, \\\"Putting\\\": 1, \\\"The\\\": 12, \\\"There\\\": 8, \\\"No\\\": 2, \\\"This\\\": 5, \\\"Then\\\": 1, \\\"Not\\\": 5, \\\"And\\\": 3, \\\"Now,\\\": 1, \\\"Teal'c's\\\": 1, \\\"With\\\": 3, \\\"Or,\\\": 2, \\\"I'm\\\": 3, \\\"However,\\\": 1, \\\"Jack\\\": 34, \\\"So\\\": 2, \\\"Teal'c\\\": 7, \\\"Considering\\\": 3, \\\"He\\\": 29, \\\"Daniel,\\\": 1, \\\"Why\\\": 2, \\\"No,\\\": 2, \\\"Still,\\\": 2, \\\"A\\\": 4, \\\"From\\\": 3, \\\"They'll\\\": 1, \\\"We\\\": 3, \\\"They\\\": 3, \\\"As\\\": 4, \\\"If\\\": 1, \\\"Killing\\\": 1, \\\"They're\\\": 3, \\\"I\\\": 2, \\\"Don't\\\": 1, \\\"Yeah,\\\": 1, \\\"It\\\": 6, \\\"Disgusted,\\\": 1, \\\"Her\\\": 12, \\\"Boots\\\": 1, \\\"Plus,\\\": 1, \\\"After\\\": 1, \\\"Carter\\\": 12, \\\"She\\\": 22, \\\"Almost\\\": 1, \\\"On\\\": 1, \\\"Wary\\\": 1, \\\"Getting\\\": 1, \\\"
# Models loaded
# For a moment, she allowed herself to cry, cry for him and the slow spread of it across her face followed by the rest of his life.
# “Maybe we were just… you know… a bit of a surprise to the members of SG-1.
# “I’ll get you a gift that you would wish to participate.
# He’d told her to pack some warm clothes along with shorts and a tank top.“Do you have a few minutes?
# Not only did it have the fireplace Jack mentioned but it also makes him think of that future they might have held it in both his hands, studied it instead of her.
# “Can anyone join this party?”Sam’s eyes flew up to his, her cheek on his shoulder.
# Handing the freshly-assembled plate to a nearby airman, she slipped out of the corner of her eye, Sam watched him begin clearing the empty glass beer bottles and adding them to the small space between them.ooooIt’s different when he doesn’t eat regularly.”“Yeah, yeah,” Jack said, slightly breathless.
# Besides, he genuinely couldn't think of anything he could do about it if he just gave it a squeeze.Alana ignored her behavior, clearly accustomed to it.
# The eyewash worked and he could do about it.“No, sir.
# His hands hold her face to his as if she’s searching for something.
# Leaning over to retrieve a piece of chocolate and giving him privacy.“Oh, Sam.”
# He kicks off his shoes and lays on the horn for just a second with a glass of white wine.
# The skin around her leg is still red and angry, knitted together with the best steaks on this whole planet, but if we're gonna make it nice for her.”“Let’s not get wine,” Carter says, suddenly.
# She grows up with a decorated General she has wrapped around her little finger, and Cassie had always known it.
# But it didn’t matter, because the village people wanted to talk to about what happened—“ “I’m fine, sir.”
# Sam turned to sit beside her, leaving a respectable distance between them and she doesn’t know how to process the loss of Sha’re, Skaara and Kawalsky, to trying to solve a puzzle to keep from shivering.
# No, they weren't supposed to be a routine mission.
# When he turned back around Carter was standing in his entry, exactly where he left her standing so he could wrap his arms around her, and pulled her into his arms and kiss her lips.
# “Carter, let’s go!”They weren’t far now and she would find the room with relief.
# The dress she wore was an indescribable shade of pink she flushes inside when her blood is stirring.
# Saved file.

# %%
with open('data/full_model_spacy', 'r') as f:
    raw = f.read()
model_json = json.loads(raw)
model = POSifiedText.from_json(model_json)
print('Loaded model.')
# Out:
# Loaded model.

# %%
quit = False
while quit == False:
    num_sent = input('Enter # of sentences to generate or q to quit: ')
    if num_sent == 'q':
        quit = True
    else:
        for i in range(int(num_sent)):
            print(model.make_sentence())
# Out:
# Other than that, he may as well have been a mine at one time, but if you become a nuisance…”“I won’t, I promise!”“Right.”
# The attack on Per'sus, the suicide of Lieutenant Astor, finding out that she and the Colonel were dead and Daniel in intellectual matters, but it didn’t matter that he was the one who'd just been abducted and auctioned off.
# Really, Jack had much more in common with a windowless tomb than an apartment.
# The person I’ve wanted, whom I’ve needed has been here before, after all, and he’d gone to bed first.
# “Funny.”“Jets or Sharks, we should probably take our seats,” Daniel says and looks back at her and then turned away.
# He knew how she felt.
# Jack put a hand on her hand from her shoulder to her back and his hand turned under hers so that their kiss deepened.
# She told him, looking up into the night sky.
# Teal’c settled himself back on the bed in the semi-darkness.
# Don’t think we’ve met but he’s probably not going to be incredibly sensitive under his mouth, at least at some point in watching these stupid movies, I came to visit?”“Better than okay,” Jack says.
# He nibbled the side of his major; the side that lets him view the woman behind the woman he still held so much back from her.
# “I told her people do it all the time, but he really did know his stuff.
# This wasn't working; she knew what he was doing, he waved the invitation at her.
# She couldn’t help the twitch that drew the corner of his eyes he gave her a ring.”Daniel look confused for a moment, because something fierce is welling up.
# A computer screen - the old fashioned sort - swirled a maze of individual gardens before depositing him into another clearing.
# No one except the two of them Jack turned his head just enough to offer an insanely tempting view.
# None
# He'd barely been able to put it back in his chair.
# None
# ~*~*~*~*~*~*~*~ Jack stepped back into the tent with a solemn nod and turned back to her.
# Before Joe’s death, before her father left for a second and gave Daniel the smallest twitch of her lips into a soft Oh.
# Jonas, on the other hand, had been in there long enough when he realized he wasn’t swaying, the ground was.Just as he realized that she wasn't going to be an interesting story.
# In the parking lot, and turns to Carter.
# Even though she hadn't been harmed - that she was trying to tell herself, anyway.
# But that’s not why I called.”“No,” he says nodding and staring down at a more than startled SG-1, Sam realized that their plan had failed.
# He pulls away when his hand suddenly grasps her frozen one.
# She shook her head, grinning at him as she spoke, and Sam knew that if SG1 was home, that it was any of his business.He decided to let it go.
# The hours in the air between them.
# He closed his eyes and headed into the yard to where Teal’c was waiting and she would quickly slide into a deeper, more restful sleep.
# But I can tell is that whatever they were tracking, but there are tears in her eyes.“Any change?”
# She’s got a little sheen across her forehead and she had agreed, knowing what she hoped he had meant by that, but she didn’t feel it.
# None
# Suddenly, it was not quite anything Jack could put his finger on, but he didn't care.
# It was so infrequent that it always meant more when he pointed out her rosy cheeks, and then she allows her eyes to hold their position.
# He waves a careless hand around in the frothy water that reached the shore.
# He remembered that now, too “They are . . . hope . . . close with someone . . . ” Daniel raced to another table, snatching a paper cup of pills and some water next to her ear and away from her work bench in shock.
# But she’s always happier when she’s in bed with empty arms, wishing for someone to share my life with?
# “We absolutely cannot let your half birthday go by without some sort of bad dream, and I tried to wake you up.
# “You don’t give a damn what time it is, and I suggested we get Daniel to take a phone call that would be highly inadvisable.
# The colonel got him a membership to a local outdoor outfitter but a glance at herself in the mirror because that’s not really my problem.
# “Yes, sir.”He nodded and took a closer look at her.
# He gave her a gentle push to make her smile.
# His voice sounded dangerously like he'd been thinking exactly what she wanted and even when it was time to head back to get closer.
# But it had to end and she knew how much of her time covered in dirt or grease, but she tried to look at her.
# But he was in charge of the base, he was pretty sure awkwardness was unavoidable as well.
# Not that it was over between him and the floodgates opened.
# Yes, he thought, slowly rotating the chair and placed her hand on his shoulder.
# And, she thought as she broke eye contact and looked away, discarding her bra onto the bed beside her, rubbing the back of her head before laughing softly.
# “You can ask me all your questions tomorrow during the appointed check-in time.”“But …”He tuned out her technobabble as she tried to figure out where he’d flung his cell earlier.
# He maintained a hold on her as it was a few inches away from hers, their knees closer than they should be, on the other end of the dock underneath her.
# “Colonel…” she starts, unsure of what to say and then when she does speak, she looks like she might just burst into tears, hadn’t.
# It wasn’t helping, even though he really does think Daniel would like it if you’d just go now.”
# It was our mess so we had to leave it in the room, you mean?” he guessed.She winced.
# Wow, this close, she was reminded of how tall he was – and how it sounds when he says her name near the end.
# I know I never would have found her in that way, especially while on a mission.
# Irritated, Daniel stands up and pushes his chair back with a sad smile then followed Gable towards the palace.
# She couldn't speak; she just nodded and let him lead her out into the hallway to the bathroom.
# Well, at least there was one of the many amulets that hung around his neck.
# After a traumatic event, there are those who want constant company and while Carter tries to be the father of your children.”
# Turning her head, she looked at him questioningly.“Screw regs.”
# Would he look at her before they stepped through the Stargate are not commonalities.”
# They followed the older couple left, no doubt to the bottle in his hands, he told her, this time careful to eat her hot dog before the start of something… more.
# None
# He smiled into a kiss, his hands wandering up to her and hopes the guys take a while to wade out of the darkness, the light from the hall spilling across the room to try to fix things.
# “Sir,” she breathes, before Jack’s lips cover hers and his tee shirt in order to get a bottle of beer, grabbing the hem of her shirt upwards, ready to consider lifting it up and read it anyway.
# Jack narrowed his eyes at just the right resonance to reverberate unpleasantly in his skull.
# The more stunts he tried to take it out.
# “I couldn’t sleep, Sir.” she said, biting her lower lip as she tried to understand the technical side of the bed and laid her down, snagging his pack with his foot and dragging it over.
# Sam hauled her pack into the back of a visitor’s chair, evidence Teal’c had stopped by.
# Willing himself to try to finish the simulation.
# She'd done far too much fighting for her life on her own lips.Unconsciously mirroring his movement, Sam moistened her lips too.
# Somehow, that made the hair on his arms stand up and loudly clear his throat.The goa’uld turned just in time to say, “Before someone eats all the cake.”Daniel gives him a jolt low in his belly when he realized both Teal’c and Daniel and… and with you,” she says, fresh tears sliding down her face went unnoticed by her.
# It’s the second awkward meal she has had out in the middle of a fancy steakhouse.He turned to the awaiting group.“All right.”
# Her mouth is dry, she licks her lips and then searching for her clit.
# He wanted her to meet his gaze.
# Memory loss and confusion - that would be a shame to waste that dress.”
# His eyes popped when he saw her brief nod and continued.
# “I don’t--I don’t know wh--”The ambassador at the head of the lamp so its rays will touch everything in the small tent, snaking her arm carefully around his middle, doing her best not to look at him, he continued.
# She's stopped trying to tell them they don’t need to sleep, and he’d still be with them, but the core functions of the SGC to sleep.
# None
# He’d been so angry before, but now that everyone was home and they were still there, draped over the back of the dresser.
# She met his steady gaze, and had to blink some more just to make sure it sticks and then stands up with him so that his lips are now by Sam’s ear.
# “Except now you know I…”“And you know that I am, indeed, a rare breed of awesome.”
# He nestled in so that he could spend a few days after they had met each other, wasn’t it?”
# Sam looked back to Sam – who gave him one of Janet’s nice pills.
# “Remember when I got lost on the Prometheus?”He gives her a stern look but decides it’s too cold to care.
# “Oh come on, Carter, what could possibly ever matter again?Carter was dead.He knew grief.
# Fraiser said as she handed it to him.Jack ran a finger thoughtfully along one of the first benefits of the treaty.
# If this was how they looked in the fridge if…” her voice trailed off.“What?”
# “Did you need something, sir?”He rubbed the back of one of your culture’s deities?”“If you mean Christmas, than yes.
# “If you’re sure it won’t be in regular old English.
# It was our mess so we had to do it, she told him since he'd skipped out doing most of the way she emphasized her words with his fingers and smile benevolently, Jack knew he was aroused.
# But there was no sense in fleeing; the damage was only temporary, and already appeared to be part of the equation.
# While not everything on P3R-118 had been bad, she thought it possible that his wandering hand might have gotten the place ready for you.”
# There are no tiny bottles of alcohol they don’t really need to say the Colonel would have shut it down, and probably would have if it hadn’t been for Selmak, she’d have lost Jacob four years ago.
# Carter shot him a look.
# A cascade of water hit them both and thinks he probably should have dragged you off somewhere to have my plans change unexpectedly.”
# Too late, he’d remembered Sam, but Jack was saved from having to come up with an idea.
# Sam's shoulders shuddered, until she turned the corner.
# I love being a part of the day.
